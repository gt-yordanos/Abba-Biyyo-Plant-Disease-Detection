# %%
# !pip install tensorflow matplotlib seaborn
# Out:
# Requirement already satisfied: tensorflow in c:\users\gtyor\appdata\local\programs\python\python311\lib\site-packages (2.19.0)
# Requirement already satisfied: matplotlib in c:\users\gtyor\appdata\local\programs\python\python311\lib\site-packages (3.10.1)
# Requirement already satisfied: seaborn in c:\users\gtyor\appdata\local\programs\python\python311\lib\site-packages (0.13.2)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\gtyor\appdata\local\programs\python\python311\lib\site-packages (from tensorflow) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\gtyor\appdata\local\programs\python\python311\lib\site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in c:\users\gtyor\appdata\local\programs\python\python311\lib\site-packages (from tensorflow) (25.1.24)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\gtyor\appdata\local\programs\python\python311\lib\site-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\gtyor\appdata\local\programs\python\python311\lib\site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\gtyor\appdata\local\programs\python\python311\lib\site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\gtyor\appdata\local\programs\python\python311\lib\site-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in c:\users\gtyor\appdata\local\programs\python\python311\lib\site-packages (from tensorflow) (24.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in c:\users\gtyor\appdata\local\programs\python\python311\lib\site-packages (from tensorflow) (5.29.3)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\gtyor\appdata\local\programs\python\python311\lib\site-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in c:\users\gtyor\appdata\local\programs\python\python311\lib\site-packages (from tensorflow) (65.5.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\gtyor\appdata\local\programs\python\python311\lib\site-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\gtyor\appdata\local\programs\python\python311\lib\site-packages (from tensorflow) (2.5.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\gtyor\appdata\local\programs\python\python311\lib\site-packages (from tensorflow) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\gtyor\appdata\local\programs\python\python311\lib\site-packages (from tensorflow) (1.17.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\gtyor\appdata\local\programs\python\python311\lib\site-packages (from tensorflow) (1.70.0)
# Requirement already satisfied: tensorboard~=2.19.0 in c:\users\gtyor\appdata\local\programs\python\python311\lib\site-packages (from tensorflow) (2.19.0)
# Requirement already satisfied: keras>=3.5.0 in c:\users\gtyor\appdata\local\programs\python\python311\lib\site-packages (from tensorflow) (3.9.2)
# Requirement already satisfied: numpy<2.2.0,>=1.26.0 in c:\users\gtyor\appdata\local\programs\python\python311\lib\site-packages (from tensorflow) (2.0.2)
# Requirement already satisfied: h5py>=3.11.0 in c:\users\gtyor\appdata\local\programs\python\python311\lib\site-packages (from tensorflow) (3.12.1)
# Requirement already satisfied: ml-dtypes<1.0.0,>=0.5.1 in c:\users\gtyor\appdata\local\programs\python\python311\lib\site-packages (from tensorflow) (0.5.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\gtyor\appdata\local\programs\python\python311\lib\site-packages (from tensorflow) (0.31.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\gtyor\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\gtyor\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\gtyor\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\gtyor\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: pillow>=8 in c:\users\gtyor\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\gtyor\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\gtyor\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: pandas>=1.2 in c:\users\gtyor\appdata\local\programs\python\python311\lib\site-packages (from seaborn) (2.2.3)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\gtyor\appdata\local\programs\python\python311\lib\site-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: rich in c:\users\gtyor\appdata\local\programs\python\python311\lib\site-packages (from keras>=3.5.0->tensorflow) (13.9.4)
# Requirement already satisfied: namex in c:\users\gtyor\appdata\local\programs\python\python311\lib\site-packages (from keras>=3.5.0->tensorflow) (0.0.8)
# Requirement already satisfied: optree in c:\users\gtyor\appdata\local\programs\python\python311\lib\site-packages (from keras>=3.5.0->tensorflow) (0.14.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\gtyor\appdata\local\programs\python\python311\lib\site-packages (from pandas>=1.2->seaborn) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\gtyor\appdata\local\programs\python\python311\lib\site-packages (from pandas>=1.2->seaborn) (2025.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\gtyor\appdata\local\programs\python\python311\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\gtyor\appdata\local\programs\python\python311\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\gtyor\appdata\local\programs\python\python311\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\gtyor\appdata\local\programs\python\python311\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2024.12.14)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\gtyor\appdata\local\programs\python\python311\lib\site-packages (from tensorboard~=2.19.0->tensorflow) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\gtyor\appdata\local\programs\python\python311\lib\site-packages (from tensorboard~=2.19.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\gtyor\appdata\local\programs\python\python311\lib\site-packages (from tensorboard~=2.19.0->tensorflow) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\gtyor\appdata\local\programs\python\python311\lib\site-packages (from werkzeug>=1.0.1->tensorboard~=2.19.0->tensorflow) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\gtyor\appdata\local\programs\python\python311\lib\site-packages (from rich->keras>=3.5.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\gtyor\appdata\local\programs\python\python311\lib\site-packages (from rich->keras>=3.5.0->tensorflow) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\gtyor\appdata\local\programs\python\python311\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow) (0.1.2)

# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import os
import shutil

# %%
# Define dataset directories
train_dir = "train"
val_dir = "val"
test_dir = "test"

# %%
training_set = tf.keras.utils.image_dataset_from_directory(
    train_dir,
    labels="inferred",
    label_mode="categorical",
    class_names=None,
    color_mode="rgb",
    batch_size=32,
    image_size=(128, 128),
    shuffle=True,
    seed=None,
    validation_split=None,
    subset=None,
    interpolation="bilinear",
    follow_links=False,
    crop_to_aspect_ratio=False
)
# Out:
# Found 12401 files belonging to 4 classes.

# %%
validation_set = tf.keras.utils.image_dataset_from_directory(
    val_dir,
    labels="inferred",
    label_mode="categorical",
    class_names=None,
    color_mode="rgb",
    batch_size=32,
    image_size=(128, 128),
    shuffle=True,
    seed=None,
    validation_split=None,
    subset=None,
    interpolation="bilinear",
    follow_links=False,
    crop_to_aspect_ratio=False
)
# Out:
# Found 3098 files belonging to 4 classes.

# %% [markdown]
# # **Building The Model**

# %%
cnn = tf.keras.models.Sequential()

# %% [markdown]
# **Building Convolution Layer**

# %%
cnn.add(tf.keras.layers.Conv2D(filters=32,kernel_size=3,padding='same',activation='relu',input_shape=[128,128,3]))
cnn.add(tf.keras.layers.Conv2D(filters=32,kernel_size=3,activation='relu'))
cnn.add(tf.keras.layers.MaxPool2D(pool_size=2,strides=2))
# Out:
# C:\Users\gtyor\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
cnn.add(tf.keras.layers.Conv2D(filters=64,kernel_size=3,padding='same',activation='relu'))
cnn.add(tf.keras.layers.Conv2D(filters=64,kernel_size=3,activation='relu'))
cnn.add(tf.keras.layers.MaxPool2D(pool_size=2,strides=2))

# %%
cnn.add(tf.keras.layers.Conv2D(filters=128,kernel_size=3,padding='same',activation='relu'))
cnn.add(tf.keras.layers.Conv2D(filters=128,kernel_size=3,activation='relu'))
cnn.add(tf.keras.layers.MaxPool2D(pool_size=2,strides=2))

# %%
cnn.add(tf.keras.layers.Conv2D(filters=256,kernel_size=3,padding='same',activation='relu'))
cnn.add(tf.keras.layers.Conv2D(filters=256,kernel_size=3,activation='relu'))
cnn.add(tf.keras.layers.MaxPool2D(pool_size=2,strides=2))

# %%
cnn.add(tf.keras.layers.Conv2D(filters=512,kernel_size=3,padding='same',activation='relu'))
cnn.add(tf.keras.layers.Conv2D(filters=512,kernel_size=3,activation='relu'))
cnn.add(tf.keras.layers.MaxPool2D(pool_size=2,strides=2))

# %%
cnn.add(tf.keras.layers.Dropout(0.25))

# %%
cnn.add(tf.keras.layers.Flatten())

# %%
cnn.add(tf.keras.layers.Dense(units=1500,activation='relu'))

# %%
cnn.add(tf.keras.layers.Dropout(0.4)) #To avoid overfitting

# %%
#Output Layer
cnn.add(tf.keras.layers.Dense(units=4,activation='softmax'))

# %% [markdown]
# **Compiling and Training Phase**

# %%
cnn.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# %%
cnn.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                      │ (None, 128, 128, 32)        │             896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 126, 126, 32)        │           9,248 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 63, 63, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_2 (Conv2D)                    │ (None, 63, 63, 64)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_3 (Conv2D)                    │ (None, 61, 61, 64)          │          36,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 30, 30, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_4 (Conv2D)                    │ (None, 30, 30, 128)         │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_5 (Conv2D)                    │ (None, 28, 28, 128)         │         147,584 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_2 (MaxPooling2D)       │ (None, 14, 14, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_6 (Conv2D)                    │ (None, 14, 14, 256)         │         295,168 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_7 (Conv2D)                    │ (None, 12, 12, 256)         │         590,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_3 (MaxPooling2D)       │ (None, 6, 6, 256)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_8 (Conv2D)                    │ (None, 6, 6, 512)           │       1,180,160 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_9 (Conv2D)                    │ (None, 4, 4, 512)           │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_4 (MaxPooling2D)       │ (None, 2, 2, 512)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 2, 2, 512)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 2048)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 1500)                │       3,073,500 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 1500)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 4)                   │           6,004 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 7,791,728 (29.72 MB)
#  Trainable params: 7,791,728 (29.72 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
from tensorflow.keras.callbacks import ModelCheckpoint

# Callback to save best model based on val_loss
checkpoint = ModelCheckpoint(
    filepath='CornDisease_best_val_loss.keras',
    monitor='val_loss',
    save_best_only=True,
    mode='min',
    verbose=1
)

training_history = cnn.fit(
    x=training_set,
    validation_data=validation_set,
    epochs=10,
    callbacks=[checkpoint]
)
# Out:
# Epoch 1/10
# 388/388 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6906 - loss: 0.7712
# Epoch 1: val_loss improved from inf to 0.24333, saving model to CornDisease_best_val_loss.keras
# 388/388 ━━━━━━━━━━━━━━━━━━━━ 502s 1s/step - accuracy: 0.6910 - loss: 0.7704 - val_accuracy: 0.9158 - val_loss: 0.2433
# Epoch 2/10
# 388/388 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9213 - loss: 0.2325
# Epoch 2: val_loss improved from 0.24333 to 0.22515, saving model to CornDisease_best_val_loss.keras
# 388/388 ━━━━━━━━━━━━━━━━━━━━ 529s 1s/step - accuracy: 0.9213 - loss: 0.2325 - val_accuracy: 0.9112 - val_loss: 0.2251
# Epoch 3/10
# 388/388 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9315 - loss: 0.1897
# Epoch 3: val_loss improved from 0.22515 to 0.16764, saving model to CornDisease_best_val_loss.keras
# 388/388 ━━━━━━━━━━━━━━━━━━━━ 462s 1s/step - accuracy: 0.9315 - loss: 0.1897 - val_accuracy: 0.9419 - val_loss: 0.1676
# Epoch 4/10
# 388/388 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9484 - loss: 0.1462
# Epoch 4: val_loss did not improve from 0.16764
# 388/388 ━━━━━━━━━━━━━━━━━━━━ 465s 1s/step - accuracy: 0.9484 - loss: 0.1463 - val_accuracy: 0.9454 - val_loss: 0.1837
# Epoch 5/10
# 388/388 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9502 - loss: 0.1465
# Epoch 5: val_loss did not improve from 0.16764
# 388/388 ━━━━━━━━━━━━━━━━━━━━ 466s 1s/step - accuracy: 0.9502 - loss: 0.1465 - val_accuracy: 0.9393 - val_loss: 0.1816
# Epoch 6/10
# 388/388 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9591 - loss: 0.1199
# Epoch 6: val_loss did not improve from 0.16764
# 388/388 ━━━━━━━━━━━━━━━━━━━━ 463s 1s/step - accuracy: 0.9591 - loss: 0.1199 - val_accuracy: 0.9390 - val_loss: 0.1867
# Epoch 7/10
# 388/388 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9623 - loss: 0.1078
# Epoch 7: val_loss did not improve from 0.16764
# 388/388 ━━━━━━━━━━━━━━━━━━━━ 466s 1s/step - accuracy: 0.9623 - loss: 0.1078 - val_accuracy: 0.9393 - val_loss: 0.1847
# Epoch 8/10
# 388/388 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9632 - loss: 0.1035
# Epoch 8: val_loss did not improve from 0.16764
# 388/388 ━━━━━━━━━━━━━━━━━━━━ 466s 1s/step - accuracy: 0.9632 - loss: 0.1035 - val_accuracy: 0.9183 - val_loss: 0.2632
# Epoch 9/10
# 388/388 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9742 - loss: 0.0773
# Epoch 9: val_loss did not improve from 0.16764
# 388/388 ━━━━━━━━━━━━━━━━━━━━ 471s 1s/step - accuracy: 0.9742 - loss: 0.0773 - val_accuracy: 0.9442 - val_loss: 0.2025
# Epoch 10/10
# 388/388 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9755 - loss: 0.0702
# Epoch 10: val_loss did not improve from 0.16764
# 388/388 ━━━━━━━━━━━━━━━━━━━━ 526s 1s/step - accuracy: 0.9756 - loss: 0.0702 - val_accuracy: 0.9448 - val_loss: 0.2535

# %%
#Training set Accuracy
train_loss, train_acc = cnn.evaluate(training_set)
print('Training accuracy:', train_acc)

#Validation set Accuracy
val_loss, val_acc = cnn.evaluate(validation_set)
print('Validation accuracy:', val_acc)
# Out:
# 388/388 ━━━━━━━━━━━━━━━━━━━━ 113s 291ms/step - accuracy: 0.9755 - loss: 0.0685
# Training accuracy: 0.9788726568222046
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 30s 313ms/step - accuracy: 0.9461 - loss: 0.2584
# Validation accuracy: 0.9448031187057495

# %%
cnn.save('cornDisease.keras')

# %%
import matplotlib.pyplot as plt

epochs = [i for i in range(1, 11)]

fig, axs = plt.subplots(1, 2, figsize=(14, 5))  # 1 row, 2 columns

# --- Accuracy plot ---
axs[0].plot(epochs, training_history.history['accuracy'], color='red', label='Training Accuracy')
axs[0].plot(epochs, training_history.history['val_accuracy'], color='blue', label='Validation Accuracy')
axs[0].set_title('Accuracy over Epochs')
axs[0].set_xlabel('Epoch')
axs[0].set_ylabel('Accuracy')
axs[0].legend()

# --- Loss plot ---
axs[1].plot(epochs, training_history.history['loss'], color='orange', label='Training Loss')
axs[1].plot(epochs, training_history.history['val_loss'], color='green', label='Validation Loss')
axs[1].set_title('Loss over Epochs')
axs[1].set_xlabel('Epoch')
axs[1].set_ylabel('Loss')
axs[1].legend()

plt.tight_layout()
plt.show()

# %%
class_name = validation_set.class_names

# %%
test_set = tf.keras.utils.image_dataset_from_directory(
    'val',
    labels="inferred",
    label_mode="categorical",
    class_names=None,
    color_mode="rgb",
    batch_size=1,
    image_size=(128, 128),
    shuffle=False,
    seed=None,
    validation_split=None,
    subset=None,
    interpolation="bilinear",
    follow_links=False,
    crop_to_aspect_ratio=False
)
# Out:
# Found 3098 files belonging to 4 classes.

# %%
y_pred = cnn.predict(test_set)
predicted_categories = tf.argmax(y_pred, axis=1)

true_categories = tf.concat([y for x, y in test_set], axis=0)
Y_true = tf.argmax(true_categories, axis=1)
# Out:
# 3098/3098 ━━━━━━━━━━━━━━━━━━━━ 73s 24ms/step

# %%
Y_true
# Out:
# <tf.Tensor: shape=(3098,), dtype=int64, numpy=array([0, 0, 0, ..., 3, 3, 3])>

# %%
predicted_categories
# Out:
# <tf.Tensor: shape=(3098,), dtype=int64, numpy=array([0, 0, 0, ..., 3, 3, 3])>

# %%
from sklearn.metrics import confusion_matrix,classification_report
cm = confusion_matrix(Y_true,predicted_categories)

# %%
# Precision Recall Fscore
print(classification_report(Y_true,predicted_categories,target_names=class_name))
# Out:
#                        precision    recall  f1-score   support
#
#    Corn___Common_Rust       0.95      0.98      0.97       792
# Corn___Gray_Leaf_Spot       0.94      0.87      0.90       713
#        Corn___Healthy       0.96      0.99      0.98       781
#    Corn___Leaf_Blight       0.93      0.93      0.93       812
#
#              accuracy                           0.94      3098
#             macro avg       0.94      0.94      0.94      3098
#          weighted avg       0.94      0.94      0.94      3098

# %%
plt.figure(figsize=(40, 40))
sns.heatmap(cm,annot=True,annot_kws={"size": 10})

plt.xlabel('Predicted Class',fontsize = 20)
plt.ylabel('Actual Class',fontsize = 20)
plt.title('Plant Disease Prediction Confusion Matrix',fontsize = 25)
plt.show()

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing import image
import os

# Load the trained model
model = tf.keras.models.load_model('CornDisease.keras')

# Define image size (must match what was used during training)
image_size = (128, 128)

# Path to test images
test_dir = "test"

# Get class names from model (if saved with metadata or known ahead of time, define here)
# Example: manually define if needed
class_names = ['Corn___Common_Rust', 'Corn___Gray_Leaf_Spot', 'Corn___Healthy', 'Corn___Leaf_Blight']

# Function to load image
def load_image(img_path):
    img = image.load_img(img_path, target_size=image_size)
    img_array = image.img_to_array(img)
    img_array = np.expand_dims(img_array, axis=0)
    return img_array

# Function to predict and show result
def predict_image(img_path):
    img_array = load_image(img_path)
    prediction = model.predict(img_array)
    predicted_class = class_names[np.argmax(prediction)]
    confidence = np.max(prediction)

    img = image.load_img(img_path, target_size=image_size)
    plt.imshow(img)
    plt.title(f"Predicted: {predicted_class} ({confidence * 100:.2f}%)")
    plt.axis('off')
    plt.show()

# Test each image in the test folder
for file in os.listdir(test_dir):
    img_path = os.path.join(test_dir, file)
    if os.path.isfile(img_path) and file.lower().endswith(('.jpg', '.jpeg', '.png')):
        print(f"Testing: {file}")
        predict_image(img_path)
# Out:
# Testing: CommonRust.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 266ms/step
# Testing: CommonRust1.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# Testing: GrayLeaf (2).jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# Testing: GrayLeaf1.JPG
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# Testing: GrayLeaf2.JPG
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# Testing: GrayLeaf3.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# Testing: GrayLeaf4.JPG
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# Testing: GrayLeaf5.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# Testing: Healthy1.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# Testing: Healthy2.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# Testing: Healthy3.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# Testing: Healthy4.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# Testing: Healthy5.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# Testing: healthy7.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# Testing: healthy8.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# Testing: LeafBlight6 (1).jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# Testing: LeafBlight6 (2).jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# Testing: LeafBlight6 (3).jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# Testing: LeaftBlight1.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# Testing: LeaftBlight2.JPG
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# Testing: LeaftBlight3.JPG
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# Testing: LeaftBlight4.JPG
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# Testing: LeaftBlight5.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# Testing: LeaftBlight6.JPG
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# Testing: RS_Rust 1563(1).JPG
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# Testing: RS_Rust 1601(1).JPG
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# Testing: RS_Rust 1608_flipLR(1).JPG
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# Testing: RS_Rust 1648.JPG
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# Testing: RS_Rust 1651.JPG
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# Testing: RS_Rust 1715_flipLR.JPG
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
